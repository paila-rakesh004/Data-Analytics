# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


file_path = 'covid_data.csv'
df = pd.read_csv(file_path)





df.fillna({'continents' : "Unknown"}, inplace=True)


df = df.fillna(df.mean(numeric_only=True))

print("Data Set After Preprocessing : \n")
df.describe
# Out:
# Data Set After Preprocessing :
# <bound method NDFrame.describe of        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 429430      ZWE    Africa     Zimbabwe  2024-07-31     266386.0        0.0
# 429431      ZWE    Africa     Zimbabwe  2024-08-01     266386.0        0.0
# 429432      ZWE    Africa     Zimbabwe  2024-08-02     266386.0        0.0
# 429433      ZWE    Africa     Zimbabwe  2024-08-03     266386.0        0.0
# 429434      ZWE    Africa     Zimbabwe  2024-08-04     266386.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0              8041.025775           0.0         0.0            72.060873
# 1              8041.025775           0.0         0.0            72.060873
# 2              8041.025775           0.0         0.0            72.060873
# 3              8041.025775           0.0         0.0            72.060873
# 4              8041.025775           0.0         0.0            72.060873
# ...                    ...           ...         ...                  ...
# 429430            0.000000        5740.0         0.0             0.000000
# 429431            0.000000        5740.0         0.0             0.000000
# 429432            0.000000        5740.0         0.0             0.000000
# 429433            0.000000        5740.0         0.0             0.000000
# 429434            0.000000        5740.0         0.0             0.000000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...     33.097723                  37.746                         0.5
# 1       ...     33.097723                  37.746                         0.5
# 2       ...     33.097723                  37.746                         0.5
# 3       ...     33.097723                  37.746                         0.5
# 4       ...     33.097723                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 429430  ...     30.700000                  36.791                         1.7
# 429431  ...     30.700000                  36.791                         1.7
# 429432  ...     30.700000                  36.791                         1.7
# 429433  ...     30.700000                  36.791                         1.7
# 429434  ...     30.700000                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511    41128772
# 1                 64.83                    0.511    41128772
# 2                 64.83                    0.511    41128772
# 3                 64.83                    0.511    41128772
# 4                 64.83                    0.511    41128772
# ...                 ...                      ...         ...
# 429430            61.49                    0.571    16320539
# 429431            61.49                    0.571    16320539
# 429432            61.49                    0.571    16320539
# 429433            61.49                    0.571    16320539
# 429434            61.49                    0.571    16320539
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                 56047.6535                     9.766431
# 1                                 56047.6535                     9.766431
# 2                                 56047.6535                     9.766431
# 3                                 56047.6535                     9.766431
# 4                                 56047.6535                     9.766431
# ...                                      ...                          ...
# 429430                            56047.6535                     9.766431
# 429431                            56047.6535                     9.766431
# 429432                            56047.6535                     9.766431
# 429433                            56047.6535                     9.766431
# 429434                            56047.6535                     9.766431
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0              10.925353                                1772.6664
# 1              10.925353                                1772.6664
# 2              10.925353                                1772.6664
# 3              10.925353                                1772.6664
# 4              10.925353                                1772.6664
# ...                  ...                                      ...
# 429430         10.925353                                1772.6664
# 429431         10.925353                                1772.6664
# 429432         10.925353                                1772.6664
# 429433         10.925353                                1772.6664
# 429434         10.925353                                1772.6664
#
# [429435 rows x 67 columns]>

# %%
print("\nSummary Statistics:")
print(df.describe())
print("Mean:\n", df.mean(numeric_only=True))
print("Median:\n", df.median(numeric_only=True))
print("Count:\n", df.count())
# Out:
# Summary Statistics:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  4.294350e+05  4.294350e+05        4.294350e+05  4.294350e+05
# mean   7.365292e+06  8.017360e+03        8.041026e+03  8.125957e+04
# std    4.384702e+07  2.244512e+05        8.452280e+04  4.320384e+05
# min    0.000000e+00  0.000000e+00        0.000000e+00  0.000000e+00
# 25%    7.034000e+03  0.000000e+00        0.000000e+00  5.300000e+01
# 50%    7.501500e+04  0.000000e+00        1.657100e+01  9.400000e+02
# 75%    1.064237e+06  0.000000e+00        5.291430e+02  1.371900e+04
# max    7.758668e+08  4.423623e+07        6.319461e+06  7.057132e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  429435.000000        429435.000000            429435.000000
# mean       71.852139            72.060873            112096.199396
# std      1337.992211           501.498272            158875.006588
# min         0.000000             0.000000                 0.000000
# 25%         0.000000             0.000000              2210.990000
# 50%         0.000000             0.000000             34229.246000
# 75%         0.000000             5.429000            146788.850000
# max    103719.000000         14817.000000            763598.600000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          429435.000000                   429435.000000
# mean              122.357074                      122.713844
# std              1474.527549                      546.174965
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.000000
# 50%                 0.000000                        3.901000
# 75%                 0.000000                       81.343000
# max            241758.230000                    34536.890000
#
#        total_deaths_per_million  ...   male_smokers  handwashing_facilities  \
# count             429435.000000  ...  429435.000000           429435.000000
# mean                 835.514313  ...      33.097723               50.649264
# std                 1111.390392  ...      10.438941               19.580527
# min                    0.000000  ...       7.700000                1.188000
# 25%                   27.472000  ...      30.200000               50.649264
# 50%                  349.180000  ...      33.097723               50.649264
# 75%                 1231.202000  ...      34.800000               50.649264
# max                 6601.110000  ...      78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               429435.000000    429435.000000            429435.000000
# mean                     3.106912        73.702098                 0.722139
# std                      2.097346         7.043229                 0.128362
# min                      0.100000        53.280000                 0.394000
# 25%                      1.800000        70.390000                 0.665000
# 50%                      3.106912        74.080000                 0.722139
# 75%                      3.106912        78.920000                 0.806000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  4.294350e+05                          4.294350e+05
# mean   1.520336e+08                          5.604765e+04
# std    6.975408e+08                          2.772066e+04
# min    4.700000e+01                         -3.772610e+04
# 25%    5.237980e+05                          5.604765e+04
# 50%    6.336393e+06                          5.604765e+04
# 75%    3.296952e+07                          5.604765e+04
# max    7.975105e+09                          1.349776e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                429435.000000     429435.000000
# mean                      9.766431         10.925353
# std                       2.127729          4.340173
# min                     -44.230000        -95.920000
# 25%                       9.766431         10.925353
# 50%                       9.766431         10.925353
# 75%                       9.766431         10.925353
# max                      78.080000        378.220000
#
#        excess_mortality_cumulative_per_million
# count                            429435.000000
# mean                               1772.666400
# std                                 351.991463
# min                               -2936.453100
# 25%                                1772.666400
# 50%                                1772.666400
# 75%                                1772.666400
# max                               10293.515000
#
# [8 rows x 62 columns]
# Mean:
#  total_cases                                7.365292e+06
# new_cases                                  8.017360e+03
# new_cases_smoothed                         8.041026e+03
# total_deaths                               8.125957e+04
# new_deaths                                 7.185214e+01
#                                                ...
# population                                 1.520336e+08
# excess_mortality_cumulative_absolute       5.604765e+04
# excess_mortality_cumulative                9.766431e+00
# excess_mortality                           1.092535e+01
# excess_mortality_cumulative_per_million    1.772666e+03
# Length: 62, dtype: float64
# Median:
#  total_cases                                7.501500e+04
# new_cases                                  0.000000e+00
# new_cases_smoothed                         1.657100e+01
# total_deaths                               9.400000e+02
# new_deaths                                 0.000000e+00
#                                                ...
# population                                 6.336393e+06
# excess_mortality_cumulative_absolute       5.604765e+04
# excess_mortality_cumulative                9.766431e+00
# excess_mortality                           1.092535e+01
# excess_mortality_cumulative_per_million    1.772666e+03
# Length: 62, dtype: float64
# Count:
#  iso_code                                   429435
# continent                                  402910
# location                                   429435
# date                                       429435
# total_cases                                429435
#                                             ...
# population                                 429435
# excess_mortality_cumulative_absolute       429435
# excess_mortality_cumulative                429435
# excess_mortality                           429435
# excess_mortality_cumulative_per_million    429435
# Length: 67, dtype: int64

# %%
print("\033[1m                                                   VISUALIZATIONS\n\n\n\033[0m")



plt.figure(figsize=(8,5))
sns.countplot(x = df['continent'], data = df)
plt.title("Number of Cases In Each Continent")
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

sns.lineplot(x = df['male_smokers'], y = df['life_expectancy'])
plt.title("Life Expectency of Male Smokers")
plt.xlabel("Count of Male Smokers")
plt.ylabel("Life Expectency")
plt.grid(True)
plt.tight_layout()
plt.show()

df['continent'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("COVID Case Distribution by Continent")
plt.tight_layout()
plt.show()
# Out:
#                                                    VISUALIZATIONS
